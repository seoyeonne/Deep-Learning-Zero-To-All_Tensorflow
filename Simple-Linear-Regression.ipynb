# %%
import tensorflow as tf
x_data = [1,2,3,4,5]
y_data = [1,2,3,4,5]

w = tf.Variable(2.9)
b = tf.Variable(0.5)

#hypothesis
hypothesis = w * x_data + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - y_data))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=45.660004>

# %%
import tensorflow as tf
#tf.enable_eager_execution() 이건 뭐지 

#Data
x_data = [1,2,3,4,5]
y_data = [1,2,3,4,5]

#W, b initialize - 초기값 설정
w = tf.Variable(2.9)
b = tf.Variable(0.5)

#학습률 - 정해진 w,b 얼마나 반영할 것인지, 숫자 작을수록 조금씩 반영
learning_rate = 0.01

for i in range(100+1):
  with tf.GradientTape() as tape:
    hypothesis = w * x_data + b
    cost = tf.reduce_mean(tf.square(hypothesis - y_data))
  w_grad, b_grad = tape.gradient(cost,[w,b])
  w.assign_sub(learning_rate * w_grad)
  b.assign_sub(learning_rate * b_grad)

  if i % 10 ==0 :
    print("{:5}|{:10.4f}|{:10.4f}|{:10.6f}".format(i,w.numpy(),b.numpy(),cost))
# Out:
#     0|    2.4520|    0.3760| 45.660004
#    10|    1.1036|    0.0034|  0.206336
#    20|    1.0128|   -0.0209|  0.001026
#    30|    1.0065|   -0.0218|  0.000093
#    40|    1.0059|   -0.0212|  0.000083
#    50|    1.0057|   -0.0205|  0.000077
#    60|    1.0055|   -0.0198|  0.000072
#    70|    1.0053|   -0.0192|  0.000067
#    80|    1.0051|   -0.0185|  0.000063
#    90|    1.0050|   -0.0179|  0.000059
#   100|    1.0048|   -0.0173|  0.000055

# %%
print(w * 5 +b)
print(w * 0.5 +b)
# Out:
# tf.Tensor(5.00667, shape=(), dtype=float32)
# tf.Tensor(0.48507008, shape=(), dtype=float32)
